# %%
from ai_golf_coaches.config import load_channel_catalog
from ai_golf_coaches.utils import (
    prepare_constant_context_text,
)

# %%
catalog = load_channel_catalog("egs")
vids = [v.video_id for v in catalog if not v.is_podcast and not v.is_livestream]

# %%
print(prepare_constant_context_text(alias_or_key="egs")[0])
# Out:
# okay what's up guys hey uh we're super excited pumped because uh a little bit of a presence on a couple of different platforms Tick Tock and Instagram this gentleman TJ kathenberg really spearheading that but gonna start doing some longer form YouTube style um try to help people further their gangs through YouTube so what are we talking about well I think if we're going to start with some you know one of the main things you got to learn how to do is move face stability gotta be able to do that well before you go down but it's just like kind of thrown out like hey you need the opposite issue with your impacts because not really an explanation Beyond just that like make sure your impacts will make sure your hips are open super Limited so why don't we start with this go ahead and set up to a shot here team impact we're not talking about a specific point in space and then like right here p7 is impact you talk a lot about like everything in order so if players can start to see that impact
# ...
